# %%
import numpy as np
np.pi
# Out:
# 3.141592653589793

# %%
A = np.array([1,2,3])
for e in A: 
    print(e)

## difference between the list and np.array
L = [1, 2, 3, 4, 5]
L2 = []

for e in L:
    L2.append(e+e)

print(L2)

A = np.array([1,2,3])
2*A

# elemet-wise square 
L2 = []
for e in L:
    L2.append(e*e)

print(L2)

A**2

# dot product
a = np.array([1,2])
b = np.array([2,3])

(a*b).sum()
np.dot(a,b)
a.dot(b)
b.dot(a)

amag = np.sqrt((a*a).sum())
amag = np.linalg.norm(a)

cosangle = a.dot(b)/(np.linalg.norm(a) * np.linalg.norm(b))
cosangle

angle = np.arccos(cosangle)
print(angle)

# outer product
outer = np.outer(a, b)

Z = np.zeros((10, 10))

R = np.random.random((10, 10))
R

# gaussian distribution (input is not tuple like other functions before)
G = np.random.randn(10, 10) # mean zero variance of one
G.mean()
G.var()

# in np, element-wise multiplication is *

# first create a matrix
A = np.array([[1,2],[3,4]])
Ainv = np.linalg.inv(A)
Ainv
Ainv.dot(A)

# if you pass a 2D array to the np.linalg.diag()
# it will return the diagonal elements array
np.diag(A)
# if you pass the array, you will get diagonal matrix
np.diag([1,4])
# array([[1, 0],
#        [0, 4]])

# outer product
a = np.array([1,2])
b = np.array([3,4])
np.outer(a, b)
np.inner(a,b)
np.diag(A).sum()
np.trace(A)

# create random data
X = np.random.randn(100, 3)
cov = np.cov(X)
cov.shape
# make sure you transpose before covariance
cov = np.cov(X.T)
cov.shape

# eigen values and eigenvectors
np.linalg.eigh(cov)
np.linalg.eig(cov)

# solving linear equations
A = np.array([[1,2],[3,4]])
b = np.array([3,4])

x = np.linalg.inv(A).dot(b)
x = np.linalg.solve(A, b) # more accurate

# practice using the solve fuction
A = np.array([[1,1],[1.5, 4]])
b = np.array([2200, 5050])
x = np.linalg.solve(A,b)

# Loading in data
# X = [] # create an empty list
# for line in open("linear_regression_class/data_2d.csv"):
    # row = line.split(',')
    # sample = map(float, row)
    # X.append(sample)    row = line.split(',')
from numpy import genfromtxt
X = genfromtxt("machine_learning_examples/linear_regression_class/data_2d.csv", delimiter=',')
X.shape

# Pandas (from R background) for more complex data set
import pandas as pd 
X = pd.read_csv("machine_learning_examples/linear_regression_class/data_2d.csv", header=None)
X.info()
X.head()
X.head(10) # show first 10 rows

# X([0,0]) # no use
# M = X.as_matrix() # convert to array 
# type(M)
# Out:
# 1
# 2
# 3
# [2, 4, 6, 8, 10]
# [1, 4, 9, 16, 25]
# 0.12435499454676072
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
# 0    100 non-null float64
# 1    100 non-null float64
# 2    100 non-null float64
# dtypes: float64(3)
# memory usage: 2.4 KB
#            0          1           2
# 0  17.930201  94.520592  320.259530
# 1  97.144697  69.593282  404.634472
# 2  81.775901   5.737648  181.485108
# 3  55.854342  70.325902  321.773638
# 4  49.366550  75.114040  322.465486
# 5   3.192702  29.256299   94.618811
# 6  49.200784  86.144439  356.348093
# 7  21.882804  46.841505  181.653769
# 8  79.509863  87.397356  423.557743
# 9  88.153887  65.205642  369.229245

# %% [markdown]
# hello this is my first note $\vec{a}$
